# %%
#导入第三方包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import  stats
import scipy.stats.mstats as mst
from statsmodels.graphics.api import qqplot
dir = './data/'
df = pd.read_csv(dir+'week7.csv',engine='python',sep=",",index_col='date')
df['day_of_week']=df['day_of_week'].astype('str')
df.head(10)
# Out:
# d:\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#      day_of_week   cnt      time
# date
# 5              7  3346  20080105
# 18             7    22  20080118
# 31             7    23  20080131
# 40             7  2936  20080209
# 59             7    41  20080228
# 78             7    22  20080318
# 85             7  1929  20080325
# 98             7    36  20080407
# 105            7  1626  20080414
# 116            7    23  20080425

# %%
#dateparse = lambda dates: pd.datetime.strptime(time, '%Y/%m/%d')
#data = pd.read_csv('mian.csv', parse_dates='time', index_col='time',date_parser=dateparse)

# %%
dta=df['cnt']
type(dta)
# Out:
# pandas.core.series.Series

# %%
dta.plot(figsize=(12,8))
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
plot_acf(dta)

# %%
plot_pacf(dta)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')
    return dftest[1]#返回p值
testADF=test_stationarity(dta)
testADF
# Out:
# 4.7759983624516187e-13

# %%
t = sm.tsa.stattools.adfuller(dta)  # ADF检验
output=pd.DataFrame(index=['Test Statistic Value', "p-value", "Lags Used", "Number of Observations Used","Critical Value(1%)","Critical Value(5%)","Critical Value(10%)"],columns=['value'])
output['value']['Test Statistic Value'] = t[0]
output['value']['p-value'] = t[1]
output['value']['Lags Used'] = t[2]
output['value']['Number of Observations Used'] = t[3]
output['value']['Critical Value(1%)'] = t[4]['1%']
output['value']['Critical Value(5%)'] = t[4]['5%']
output['value']['Critical Value(10%)'] = t[4]['10%']
output
# Out:
#                                  value
# Test Statistic Value          -8.27163
# p-value                      4.776e-13
# Lags Used                            0
# Number of Observations Used         53
# Critical Value(1%)            -3.56024
# Critical Value(5%)            -2.91785
# Critical Value(10%)            -2.5968

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
#返回统计量和p值
print(u'差分序列的白噪声检验结果为：', acorr_ljungbox(dta, lags=1))
p_value1=acorr_ljungbox(dta, lags=1)[1]
# Out:
# 差分序列的白噪声检验结果为： (array([ 1.13448172]), array([ 0.2868214]))

# %%
if(p_value1<0.05):
    print('P值小于0.05，序列为平稳非白噪声序列')
else:
    print('P值大于等于0.05，序列为白噪声序列')
# Out:
# P值大于等于0.05，序列为白噪声序列

# %%
#!usr/bin/env python
#-*- coding: utf-8 -*-
#回归base model初选

import sys
import os
import time
from sklearn import metrics
import numpy as np
from sklearn import model_selection
import datetime
import sklearn
import datetime


#reload(sys)
#sys.setdefaultencoding('utf8')


# KNN Regressor
def knn_Regressor(train_x, train_y):
    from sklearn.neighbors import KNeighborsRegressor
    model = KNeighborsRegressor(n_jobs=-1)
    model.fit(train_x, train_y)
    return model


# Logistic Regression Regressor
def logistic_regression_Regressor(train_x, train_y):
    from sklearn.linear_model import LinearRegression
    model = LinearRegression(n_jobs=-1)
    model.fit(train_x, train_y)
    return model


# Random Forest Regressor
def random_forest_Regressor(train_x, train_y):
    from sklearn.ensemble import RandomForestRegressor
    model = RandomForestRegressor(n_jobs=-1)
    model.fit(train_x, train_y)
    return model


# Decision Tree Regressor
def decision_tree_Regressor(train_x, train_y):
    from sklearn import tree
    model = tree.DecisionTreeRegressor()
    model.fit(train_x, train_y)
    return model

# AdaBoostRegressor
def AdaBoostRegressor(train_x, train_y):
    from sklearn.ensemble import AdaBoostRegressor
    model = AdaBoostRegressor()
    model.fit(train_x, train_y)
    return model

# GBDT(Gradient Boosting Decision Tree) Regressor
def gradient_boosting_Regressor(train_x, train_y):
    from sklearn.ensemble import GradientBoostingRegressor
    model = GradientBoostingRegressor()
    model.fit(train_x, train_y)
    return model


# SVM Regressor
def svm_Regressor(train_x, train_y):
    from sklearn.svm import SVR
    model = SVR()
    model.fit(train_x, train_y)
    return model

def SGDRegressor(train_x, train_y):
    from sklearn.linear_model import SGDRegressor
    model = SGDRegressor(max_iter=5,tol=None)
    model.fit(train_x, train_y)
    return model


#分割数据集，生成测试和训练集
def read_data(df):
    data=df[['time']]
    target=df['cnt']
    train_x, test_x, train_y, test_y= model_selection.train_test_split(data,target)
    return train_x, test_x, train_y, test_y,

if __name__ == '__main__':
    model_score={'KNN':0, 'LR':0, 'RF':0, 'DT':0, 'SVM':0, 'GBDT':0,'ADA':0,'SGD':0}
    test_Regressors = ['KNN', 'LR','RF', 'DT','GBDT','ADA','SGD']
    Regressors = {'LR':logistic_regression_Regressor,
   'RF':random_forest_Regressor,
   'DT':decision_tree_Regressor,
  'SVM':svm_Regressor,'SGD':SGDRegressor,'KNN':knn_Regressor,
 'GBDT':gradient_boosting_Regressor,'ADA':AdaBoostRegressor
    }




    print('******************** Strating *********************')


    starttime = datetime.datetime.now()
    name=''
    temp=0
   
    for i in range(1,101):
        train_x, test_x, train_y, test_y = read_data(df)
        print(i)
        print('model training and testing data...')
        for Regressor in test_Regressors:	
            #print('******************* %s ********************' % Regressor)	
            start_time = time.time()	
            model = Regressors[Regressor](train_x, train_y)	
            #print('training took %fs!' % (time.time() - start_time))	
            predict = model.predict(test_x)
            p=predict.astype(int)
            #模型拟合测试集
            from sklearn import metrics
            # 用scikit-learn计算MSE
            mse=metrics.mean_squared_error(test_y, p)
            #print(mse)
            if(temp==0):
                temp=mse
                name=Regressor
                save_model=model
            else:
                if(temp>mse):
                    temp=mse
                    name=Regressor
                    model_score[Regressor]=model_score[Regressor]+1
                    save_model=model
        i=i+1

    endtime = datetime.datetime.now()
    print('training took %fs!' % (endtime - starttime).seconds)
    print('model name: %s' % name)
    print('lowestmse')
    print(temp)
    print(model_score)
    from sklearn.externals import joblib
    joblib.dump(save_model, dir+'my_model-week7.pkl')
    predict = save_model.predict(test_x)
    print(predict)
# Out:
# ******************** Strating *********************
# 1
# model training and testing data...
# 2
# model training and testing data...
# 3
# model training and testing data...
# 4
# model training and testing data...
# 5
# model training and testing data...
# 6
# model training and testing data...
# 7
# model training and testing data...
# 8
# model training and testing data...
# 9
# model training and testing data...
# 10
# model training and testing data...
# 11
# model training and testing data...
# 12
# model training and testing data...
# 13
# model training and testing data...
# 14
# model training and testing data...
# 15
# model training and testing data...
# 16
# model training and testing data...
# 17
# model training and testing data...
# 18
# model training and testing data...
# 19
# model training and testing data...
# 20
# model training and testing data...
# 21
# model training and testing data...
# 22
# model training and testing data...
# 23
# model training and testing data...
# 24
# model training and testing data...
# 25
# model training and testing data...
# 26
# model training and testing data...
# 27
# model training and testing data...
# 28
# model training and testing data...
# 29
# model training and testing data...
# 30
# model training and testing data...
# 31
# model training and testing data...
# 32
# model training and testing data...
# 33
# model training and testing data...
# 34
# model training and testing data...
# 35
# model training and testing data...
# 36
# model training and testing data...
# 37
# model training and testing data...
# 38
# model training and testing data...
# 39
# model training and testing data...
# 40
# model training and testing data...
# 41
# model training and testing data...
# 42
# model training and testing data...
# 43
# model training and testing data...
# 44
# model training and testing data...
# 45
# model training and testing data...
# 46
# model training and testing data...
# 47
# model training and testing data...
# 48
# model training and testing data...
# 49
# model training and testing data...
# 50
# model training and testing data...
# 51
# model training and testing data...
# 52
# model training and testing data...
# 53
# model training and testing data...
# 54
# model training and testing data...
# 55
# model training and testing data...
# 56
# model training and testing data...
# 57
# model training and testing data...
# 58
# model training and testing data...
# 59
# model training and testing data...
# 60
# model training and testing data...
# 61
# model training and testing data...
# 62
# model training and testing data...
# 63
# model training and testing data...
# 64
# model training and testing data...
# 65
# model training and testing data...
# 66
# model training and testing data...
# 67
# model training and testing data...
# 68
# model training and testing data...
# 69
# model training and testing data...
# 70
# model training and testing data...
# 71
# model training and testing data...
# 72
# model training and testing data...
# 73
# model training and testing data...
# 74
# model training and testing data...
# 75
# model training and testing data...
# 76
# model training and testing data...
# 77
# model training and testing data...
# 78
# model training and testing data...
# 79
# model training and testing data...
# 80
# model training and testing data...
# 81
# model training and testing data...
# 82
# model training and testing data...
# 83
# model training and testing data...
# 84
# model training and testing data...
# 85
# model training and testing data...
# 86
# model training and testing data...
# 87
# model training and testing data...
# 88
# model training and testing data...
# 89
# model training and testing data...
# 90
# model training and testing data...
# 91
# model training and testing data...
# 92
# model training and testing data...
# 93
# model training and testing data...
# 94
# model training and testing data...
# 95
# model training and testing data...
# 96
# model training and testing data...
# 97
# model training and testing data...
# 98
# model training and testing data...
# 99
# model training and testing data...
# 100
# model training and testing data...
# training took 35.000000s!
# model name: LR
# lowestmse
# 656664.428571
# {'KNN': 2, 'LR': 5, 'RF': 0, 'DT': 0, 'SVM': 0, 'GBDT': 0, 'ADA': 0, 'SGD': 0}
# [  742.33170178   900.24857857  1086.82266638   726.17202138   731.70080092
#    901.91965664  1083.65828452   916.17715244  1083.53384253   909.2261788
#    742.04726296   727.87865429   729.65639691   738.61621971]
