# %%
from sklearn.externals import joblib
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import scipy.stats.mstats as mst

import matplotlib as mpl
dir = './data/'
df = pd.read_table(dir + 'test_A_20171225.txt',engine='python')

# %%
df.head(10)
# Out:
#    date  day_of_week
# 0  1033            5
# 1  1034            6
# 2  1035            1
# 3  1036            2
# 4  1037            3
# 5  1038            4
# 6  1039            5
# 7  1040            6
# 8  1041            1
# 9  1042            2

# %%
from datetime import datetime
def datelist(beginDate, endDate):
    # beginDate, endDate是形如‘20160601’的字符串或datetime格式
    date_l=[datetime.strftime(x,'%Y%m%d') for x in list(pd.date_range(start=beginDate, end=endDate))]
    return date_l
df['time']=datelist('20100127','20101028')
df.head()
# Out:
#    date  day_of_week      time
# 0  1033            5  20100127
# 1  1034            6  20100128
# 2  1035            1  20100129
# 3  1036            2  20100130
# 4  1037            3  20100131

# %%
names = locals()
for i in range(1,8):
    names['week%s' % i] = df[df['day_of_week']==i]
print(week1)
# Out:
#      date  day_of_week      time
# 2    1035            1  20100129
# 8    1041            1  20100204
# 14   1047            1  20100210
# 25   1058            1  20100221
# 31   1064            1  20100227
# 37   1070            1  20100305
# 43   1076            1  20100311
# 49   1082            1  20100317
# 55   1088            1  20100323
# 62   1095            1  20100330
# 68   1101            1  20100405
# 74   1107            1  20100411
# 80   1113            1  20100417
# 86   1119            1  20100423
# 92   1125            1  20100429
# 98   1131            1  20100505
# 104  1137            1  20100511
# 110  1143            1  20100517
# 117  1150            1  20100524
# 123  1156            1  20100530
# 130  1163            1  20100606
# 136  1169            1  20100612
# 142  1175            1  20100618
# 148  1181            1  20100624
# 158  1191            1  20100704
# 165  1198            1  20100711
# 172  1205            1  20100718
# ...

# %%
from sklearn.externals import joblib
model_week1 = joblib.load('my_model-week1.pkl')
week1['cnt2'] = model_week1.predict(week1[['time']]).astype(int)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model_week2 = joblib.load('my_model-week2.pkl')
week2['cnt2'] = model_week2.predict(week2[['time']]).astype(int)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
model_week3 = joblib.load('my_model-week3.pkl')
week3['cnt2'] = model_week3.predict(week3[['time']]).astype(int)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
model_week4 = joblib.load('my_model-week4.pkl')
week4['cnt2'] = model_week4.predict(week4[['time']]).astype(int)
print(week4)
# Out:
#      date  day_of_week      time  cnt2
# 5    1038            4  20100201  1478
# 11   1044            4  20100207  1478
# 17   1050            4  20100213  1478
# 22   1055            4  20100218  1478
# 28   1061            4  20100224  1478
# 34   1067            4  20100302  1062
# 40   1073            4  20100308  1062
# 46   1079            4  20100314  1062
# 52   1085            4  20100320  1398
# 58   1091            4  20100326  1193
# 65   1098            4  20100402  1951
# 71   1104            4  20100408  1951
# 77   1110            4  20100414  1951
# 83   1116            4  20100420  1327
# 89   1122            4  20100426  1327
# 95   1128            4  20100502  1510
# 101  1134            4  20100508  1510
# 107  1140            4  20100514  1510
# 113  1146            4  20100520  1510
# 120  1153            4  20100527  4354
# 126  1159            4  20100602  2065
# 133  1166            4  20100609  1925
# 139  1172            4  20100615  1180
# ...

# %%
model_week5 = joblib.load('my_model-week5.pkl')
week5['cnt2'] = model_week5.predict(week5[['time']]).astype(int)

model_week6 = joblib.load('my_model-week6.pkl')
week6['cnt2'] = model_week6.predict(week6[['time']]).astype(int)

model_week7 = joblib.load('my_model-week7.pkl')
week7['cnt2'] = model_week7.predict(week7[['time']]).astype(int)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
names = locals()
for i in range(1,8):
    print(names['week%s' % i])
# Out:
#      date  day_of_week      time  cnt2
# 2    1035            1  20100129  2037
# 8    1041            1  20100204  2037
# 14   1047            1  20100210  2037
# 25   1058            1  20100221  2037
# 31   1064            1  20100227  2037
# 37   1070            1  20100305  2031
# 43   1076            1  20100311  2248
# 49   1082            1  20100317  2034
# 55   1088            1  20100323  1804
# 62   1095            1  20100330  1304
# 68   1101            1  20100405  2437
# 74   1107            1  20100411  2186
# 80   1113            1  20100417  1926
# 86   1119            1  20100423  2270
# 92   1125            1  20100429  2270
# 98   1131            1  20100505  1800
# 104  1137            1  20100511  1990
# 110  1143            1  20100517  3279
# 117  1150            1  20100524  3279
# 123  1156            1  20100530  3279
# 130  1163            1  20100606  2407
# 136  1169            1  20100612  2569
# 142  1175            1  20100618  2569
# ...

# %%
frames = [week1,week2,week3,week4,week5,week6,week7]
result = pd.concat(frames)
len(result)
# Out:
# 275

# %%
xgbc=joblib.load('my_model-xgbc.pkl')
result['cnt']=xgbc.predict(result[['day_of_week','cnt2','date']]).astype(int)

# %%
result=result.sort_index(axis = 0,ascending = True,by = 'date')
result.head(20)
# Out:
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#     date  day_of_week      time  cnt2   cnt
# 0   1033            5  20100127  1361  1319
# 1   1034            6  20100128   338   291
# 2   1035            1  20100129  2037  3280
# 3   1036            2  20100130  1948  2498
# 4   1037            3  20100131  1722  1862
# 5   1038            4  20100201  1478  1374
# 6   1039            5  20100202  1631  1778
# 7   1040            6  20100203   338   291
# 8   1041            1  20100204  2037  3280
# 9   1042            2  20100205  2246  2708
# 10  1043            3  20100206  1447  1346
# 11  1044            4  20100207  1478  1374
# 12  1045            5  20100208  1631  1778
# 13  1046            6  20100209   304   191
# 14  1047            1  20100210  2037  3280
# 15  1048            2  20100211  1925  2498
# ...

# %%
del result['time']
del result['day_of_week']
del result['cnt2']
result
# Out:
#      date   cnt
# 0    1033  1319
# 1    1034   291
# 2    1035  3280
# 3    1036  2498
# 4    1037  1862
# 5    1038  1374
# 6    1039  1778
# 7    1040   291
# 8    1041  3280
# 9    1042  2708
# 10   1043  1346
# 11   1044  1374
# 12   1045  1778
# 13   1046   191
# 14   1047  3280
# 15   1048  2498
# 16   1049  2076
# 17   1050  1374
# 18   1051  1319
# 19   1052   303
# 20   1053  2498
# 21   1054  1831
# 22   1055  1374
# 23   1056  1312
# 24   1057   303
# 25   1058  3280
# 26   1059  2498
# 27   1060  1831
# 28   1061  1374
# 29   1062  2031
# ..    ...   ...
# 245  1278  3017
# 246  1279  2371
# 247  1280  1978
# 248  1281  1866
# 249  1282   537
# 250  1283  3288
# 251  1284  2769
# 252  1285  2312
# 253  1286  1978
# 254  1287  1866
# 255  1288   537
# 256  1289     3
# 257  1290  3288
# 258  1291  2804
# 259  1292  2076
# 260  1293  1550
# 261  1294  1550
# 262  1295  2339
# 263  1296   330
# 264  1297     3
# 265  1298  3288
# 266  1299  3922
# 267  1300  2406
# ...

# %%
#result.to_csv('sample2.txt',index=False,header=False,)

# %%
result.to_csv('sample20180223.txt',index=False,header=False,sep='\t')
